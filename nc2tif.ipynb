# %%
import xarray as xr
import rioxarray
ds = xr.open_dataset("file.nc")
dtran = ds.transpose()
dtran.to_netcdf("nc_out.nc")

# %%
dtran
# Out:
# <xarray.Dataset> Size: 123MB
# Dimensions:            (latitude: 2969, longitude: 3452)
# Coordinates:
#   * latitude           (latitude) float32 12kB 11.52 11.52 11.52 ... 14.61 14.61
#   * longitude          (longitude) float32 14kB 79.33 79.33 ... 82.93 82.93
# Data variables:
#     Quality_indicator  (longitude, latitude) float32 41MB ...
#     SDB_type           (longitude, latitude) float32 41MB ...
#     height             (longitude, latitude) float32 41MB ...
# Attributes:
#     Conventions:       CF-1.11
#     title:             Provision of global coastal bathymetry derived from Se...
#     institution:       On behalf of the Copernicus Marine Project, https://ma...
#     source:            Sentinel 2 observations
#     history:           NetCDF file created with GGSgc NC_Makegrid version 1.7...
#     comment:           This data should not be used for navigation or any pur...
#     subset:source:     ARCO data downloaded from the Marine Data Store using ...
# ...

# %%
dtran.height.plot(x="longitude", y="latitude")

# %%
#exporting to tif
dtran.height.transpose("latitude", "longitude").rio.to_raster("height.tif")
